# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
m1=fits.open('final_output_Q0.lc')
m2=fits.open('final_output_Q1.lc')
m3=fits.open('final_output_Q2.lc')
m4=fits.open('final_output_Q3.lc')
print(m1.info())
# Out:
# Filename: final_output_Q0.lc
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      15   ()
#   1  LIGHTCURVE    1 BinTableHDU     63   7240R x 4C   [D, E, E, E]
# None

# %%
m1[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# MISSION = 'ASTROSAT'           / Name of mission/satellite
# TELESCOP= 'ASTROSAT'           / Name of mission/satellite
# INSTRUME= 'CZTI    '           / Name of Instrument/detector
# ORIGIN  =                      / Source of FITS file
# CREATOR =                      / Creator of file
# FILENAME=                      / Name of file
# CONTENT = 'LIGHT CURVE'        / File content
# DATE    =                      / Creation Date
# VERSION =                      / Extension Version Number

# %%
(m1[1].header)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   20 / width of table in bytes
# NAXIS2  =                 7240 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    4 / number of fields in each row
# TTYPE1  = 'TIME    '           / label for field   1
# TFORM1  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE2  = 'RATE    '           / label for field   2
# TFORM2  = 'E       '           / data format of field: 4-byte REAL
# TTYPE3  = 'ERROR   '           / label for field   3
# TFORM3  = 'E       '           / data format of field: 4-byte REAL
# TTYPE4  = 'FRACEXP '           / label for field   4
# TFORM4  = 'E       '           / data format of field: 4-byte REAL
# ...

# %%
m1_data = m1[1].data
print("Required Data:")
print(m1_data)
print(m1_data.shape, m1_data.dtype)
# Out:
# Required Data:
# [(3.07370636e+08, 125.48184 , 11.201868, 0.97225225)
#  (3.07370638e+08, 114.71507 , 10.710512, 0.96761477)
#  (3.07370638e+08, 111.83354 , 10.575138, 0.97466284) ...
#  (3.07377874e+08, 102.198654, 10.109335, 0.9784865 )
#  (3.07377874e+08, 113.97689 , 10.675996, 0.9738816 )
#  (3.07377876e+08, 123.04727 , 11.092668, 0.9833619 )]
# (7240,) (numpy.record, [('TIME', '>f8'), ('RATE', '>f4'), ('ERROR', '>f4'), ('FRACEXP', '>f4')])

# %%
m_complete = [m1,m2,m3,m4]
for m in m_complete:
    plt.subplots(1, 1, figsize = (15,5))
    #plt.xlim(500+3.0737e8,4200+3.0737e8)
    plt.plot(m[1].data['TIME'],m[1].data['RATE'])
    plt.xlabel("Time")
    plt.ylabel("Count Rate")

# %%
p0 = fits.open('final_output_Q0.pha')
p1 = fits.open('final_output_Q1.pha')
p2 = fits.open('final_output_Q2.pha')
p3 = fits.open('final_output_Q3.pha')

# %%
print(p0.info())
# Out:
# Filename: final_output_Q0.pha
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   ()
#   1  SPECTRUM      1 BinTableHDU     74   512R x 3C   [1J, 1E, 1E]
# None

# %%
p0[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   12 / width of table in bytes
# NAXIS2  =                  512 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    3 / number of fields in each row
# TTYPE1  = 'CHANNEL '           / PI Channel
# TFORM1  = '1J      '           / data format of field: 1-short int
# TTYPE2  = 'COUNTS  '           / Count
# TFORM2  = '1E      '           / data format of field: 2-float
# TTYPE3  = 'STAT_ERR'           / Error
# TFORM3  = '1E      '           / data format of field: 1-float
# EXTNAME = 'SPECTRUM'           / name of this binary table extension
# ERANGE  = '        '           / Energy range to generate spectrum
# ...

# %%
p_complete = [p0,p1,p2,p3]
for m in p_complete:
    plt.subplots(1, 1,figsize = (16,9))
    plt.plot(m[1].data['CHANNEL'],m[1].data['COUNTS'])
    plt.xlabel("Energy bins")
    plt.ylabel("Count rate")
